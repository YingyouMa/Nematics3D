# %% [markdown]
# # `function_name()`
#
# > **[Template note — delete before publishing]**
# > This file is a template for writing function-level tutorials and reference documentation in this repository.
# > Each section contains a blockquoted note like this one explaining what belongs there and why.
# > Delete all blockquoted template notes before publishing.
# > For readers: each section of a finished tutorial has a specific role — use this template to understand what to look for where.
# >
# > Replace `function_name()` in the title with the exact callable name as a user would type it, including parentheses.
# > If the function is a method, use `ClassName.method_name()`.
# > Below the title, write one sentence giving the function's full path and its role.
#
# `nematics3d.module_name.function_name()` — one sentence describing what this function does and which class or module it belongs to.

# %% [markdown]
# ## What `function_name()` is for
#
# > **[Template note — delete before publishing]**
# > Address three things in this section:
# > 1. What problem or need this function addresses — the user's starting point.
# > 2. At what stage of a typical workflow a user would reach for it.
# > 3. What it does internally in broad strokes — not implementation detail, but enough that the user knows what computation is being triggered.
# >
# > Keep this section short. Its purpose is to help the user decide whether this is the right function before reading further.
# > Do not describe arguments here.
#
# The main purpose of `function_name()` is to ...
#
# It is meant for the stage where ...
#
# Internally, it does several things for you in one call:
#
# - ...
# - ...
# - ...

# %% [markdown]
# ## Setup
#
# > **[Template note — delete before publishing]**
# > This section contains only code: standard imports, locating the repository root, loading example data, and creating output folders.
# > Keep it minimal. Do not explain anything here that belongs in the tutorial proper.
# > Always include the note below telling readers they can skip this section.
#
# **For readers who are only interested in the tutorial, this section can be safely skipped.** The next code cell only does setup work: it imports the package, locates the repository root, loads the bundled example data, and creates an output folder for this tutorial.

# %%
from pathlib import Path
import sys

import numpy as np
from IPython.display import Image, display


def find_repo_root() -> Path:
    candidates = [Path.cwd(), Path.cwd().parent]
    for candidate in candidates:
        if (candidate / "example" / "data" / "Q_example_workflow.npy").exists():
            return candidate
    raise FileNotFoundError(
        "Could not locate the repository root from the current working directory."
    )


REPO_ROOT = find_repo_root()

try:
    import nematics3d
except ModuleNotFoundError:
    sys.path.insert(0, str(REPO_ROOT / "src"))
    import nematics3d

DATA_PATH = REPO_ROOT / "example" / "data" / "Q_example_workflow.npy"
OUTPUT_DIR = REPO_ROOT / "tutorials" / "output" / "function_name"  # replace function_name
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print(f"Repository root: {REPO_ROOT}")
print(f"Data file: {DATA_PATH}")
print(f"Output folder: {OUTPUT_DIR}")

# %% [markdown]
# ## Minimal example
#
# > **[Template note — delete before publishing]**
# > Show the shortest call that produces a useful result. Pass only the single most important argument (or the fewest required ones).
# > The goal is to let the user copy-paste and run immediately.
# > Briefly explain each argument you do pass — even if it seems obvious.
# > Follow the code cell with: an output image if the function produces a figure, a plain-language explanation of what happened, and the two subsections below.
#
# The input here is intentionally minimal. We pass only one argument:
#
# - `arg=value`: ...

# %%
# result = nematics3d.function_name(
#     arg=value,
# )

# %% [markdown]
# > **[Template note — delete before publishing]**
# > If the function produces a figure, add an image cell here showing a representative result from a known-good run.
# > Include a sentence describing what the reader should expect to see and what may vary across environments.

# %% [markdown]
# A few things happened in that single call:
#
# - ...
# - ...
# - ...

# %% [markdown]
# ### What is returned
#
# > **[Template note — delete before publishing]**
# > State the return type(s) explicitly in the first line. Then give one sentence on each returned object explaining what it is and what the user will typically do with it next.
# > A full description of each returned object goes in the [Returned objects](#Returned-objects) section later.
#
# Returns: (`TypeA`, `TypeB`)
#
# - `result_a`: ...
# - `result_b`: ...

# %% [markdown]
# ### Reading the output
#
# > **[Template note — delete before publishing]**
# > Explain how to interpret the output of the function — what visual or numerical elements mean, how values are encoded, and what the user should pay attention to.
# > For functions that produce figures, cover each visual element (color, opacity, shape, etc.).
# > For functions that return numerical results, explain units, conventions, and how to read the values.
# > If the encoding is simple, this section can be brief or omitted.
# > Link to [Details](#Details) for deeper explanations rather than writing them here.

# %% [markdown]
# ## What is the next step?
#
# > **[Template note — delete before publishing]**
# > Point the user toward the most natural follow-up action after running this function.
# > Give concrete examples of what they might want to do next, and link to the tutorial that covers it.
# > Keep this section short — two to five bullet points and one link is enough.
#
# The most direct next step is often to ...
#
# For example, after this first call, you might want to:
#
# - ...
# - ...
#
# This workflow is covered in [next_tutorial](./next_tutorial).

# %% [markdown]
# ## Arguments
#
# > **[Template note — delete before publishing]**
# > Start with the complete function signature in a code block — all parameter names and their default values, no types or descriptions.
# > This lets the user scan all available options at a glance before reading the table.
# > Then provide the parameter table.
# > Then add one example subsection for each argument (or group of related arguments) that benefits from a concrete illustration.
# > Arguments that are self-explanatory from the table do not need their own example.
#
# ```python
# nematics3d.function_name(
#     required_arg,
#     optional_arg_1=default_1,
#     optional_arg_2=default_2,
#     optional_arg_3=default_3,
# )
# ```
#
# | Argument | What it controls | Typical form |
# | --- | --- | --- |
# | `required_arg` | ... | ... |
# | `optional_arg_1` | ... | ... |
# | `optional_arg_2` | ... | ... |
# | `optional_arg_3` | ... | ... |

# %% [markdown]
# ### Example: ...
#
# > **[Template note — delete before publishing]**
# > Each argument example subsection should have a title of the form `### Example: <what you are demonstrating>`.
# > Briefly explain what changing this argument does and when a user would want to change it.
# > Keep the explanation to two or three sentences — the code and output should do the rest.
# > If the function produces a figure, always save and display it here using `is_off_screen=True` and `display(Image(...))`.

# %%
# save_path = OUTPUT_DIR / "example_1.png"
#
# result = nematics3d.function_name(
#     required_arg=...,
#     optional_arg_1=...,
#     save_path=save_path,
#     is_off_screen=True,
# )
#
# display(Image(filename=save_path))

# %% [markdown]
# ## Usage tips
#
# > **[Template note — delete before publishing]**
# > Collect practical advice that does not fit naturally into any argument example.
# > Typical content: how to adjust parameters interactively after the call, common patterns for combining this function with others, and things the user might not think to try.
# > Each tip should have a `###` subheading.
# > This section can be omitted if there is nothing meaningful to add.
#
# ### Adjusting parameters interactively
#
# > **[Template note — delete before publishing]**
# > If the function produces an interactive figure, explain here how to access per-object control panels (right-double-click). Mention which parameters are not exposed as function arguments but can be changed interactively.
# > Link to [interact_with_figures](./interact_with_figures) for the full guide.

# %% [markdown]
# ## Returned objects
#
# > **[Template note — delete before publishing]**
# > Give one subsection per returned object.
# > For each: state the type, describe what it holds, and explain what the user would typically do with it next.
# > Link to the object's own tutorial for a full reference.
# > If the function returns a single value, this section can be a single paragraph without subsections.
#
# ### `TypeA`
#
# `result_a` is ... For a full overview, see [TypeA](./classes/TypeA/TypeA.ipynb).
#
# ### `TypeB`
#
# `result_b` is ... For a full overview, see [TypeB](./classes/TypeB/TypeB.ipynb).

# %% [markdown]
# ## Details
#
# > **[Template note — delete before publishing]**
# > This section is for readers who want to understand *how* the function works, not just *how to use* it.
# > Typical content: the algorithm or mathematical basis behind a key output, the reasoning behind a design choice, or a precise definition of a concept mentioned earlier.
# > Each topic gets a `###` subheading.
# > This section is optional reading — do not put anything here that the user *needs* in order to use the function correctly. That belongs in the argument descriptions or usage tips.
# > Link to this section from earlier in the document (e.g. "More details are shown in [Details](#Details)") rather than writing the full explanation inline.
#
# ### Topic A
#
# ...
#
# ### Topic B
#
# ...

# %% [markdown]
# ## Possible issues
#
# > **[Template note — delete before publishing]**
# > Each issue gets a `###` subheading stating the symptom as the user would observe it (not the root cause).
# > For each issue, cover: (1) what the user sees, (2) the most likely cause, (3) how to fix it or work around it.
# > Only document issues that are likely to be encountered with typical input.
# > Do not duplicate content from argument descriptions.
#
# ### Issue symptom as the user would observe it
#
# ...

# %% [markdown]
# ## Useful Links
#
# > **[Template note — delete before publishing]**
# > Collect every link that appears in the body of this document.
# > Split into two groups: links that are directly referenced in the tutorial text, and links for readers who want to go deeper.
# > Every link in the body must appear here. Every link here must appear in the body.
# > Format: `[DisplayName](path)` — description of what the linked document covers.
# > For methods, always include the class: `[ClassName.method_name()](path)`.
# >
# > **When the linked document does not exist yet:**
# > Do not leave a dead link or skip the link. Instead, create an empty placeholder notebook at the correct path first, then add the link normally. The placeholder file should have no cells — just a valid empty notebook. It will be filled in later.
# >
# > **Where to place a new notebook:**
# > The location of a tutorial or reference document mirrors the location of its corresponding source file under `src/nematics3d/`. The mapping works as follows:
# >
# > | Source file location | Tutorial location |
# > | --- | --- |
# > | `src/nematics3d/classes/SomeClass/some_method.py` | `tutorials/classes/SomeClass/some_method.ipynb` |
# > | `src/nematics3d/field.py` (a function `foo`) | `tutorials/field/foo.ipynb` |
# > | `src/nematics3d/general.py` (a function `bar`) | `tutorials/general/bar.ipynb` |
# > | `src/nematics3d/classes/grid_field/some_file.py` | `tutorials/classes/grid_field/some_method.ipynb` |
# >
# > Top-level workflow tutorials (like `quick_visualize_Q.ipynb`) that are not tied to a single source file are placed directly under `tutorials/`.
# > If the corresponding subdirectory does not exist yet, create it.
#
# ### Referenced in this tutorial
#
# - [interact_with_figures](./interact_with_figures) — guide to interacting with the figure window: rotating the camera, clicking glyphs, and opening interactive control panels
#
# ### Going deeper
#
# - ...
