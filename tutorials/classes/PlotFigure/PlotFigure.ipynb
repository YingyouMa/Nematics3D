# %% [markdown]
# # PlotFigure

# %% [markdown]
# ## Overview

# %% [markdown]
# ## Creating a figure

# %% [markdown]
# ## Adding objects

# %% [markdown]
# ## Interaction and controls

# %% [markdown]
# ## Saving and off-screen rendering
