# %% [markdown]
# # blue_red_in_white_bg()

# %% [markdown]
# ## Overview

# %% [markdown]
# ## Colormap structure

# %% [markdown]
# ## L2 normalization for white backgrounds

# %% [markdown]
# ## Usage
