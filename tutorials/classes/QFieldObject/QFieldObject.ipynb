# %% [markdown]
# # QFieldObject

# %% [markdown]
# ## Overview

# %% [markdown]
# ## Initialization

# %% [markdown]
# ## Defect detection and line classification

# %% [markdown]
# ## Visualization

# %% [markdown]
# ## Key attributes
