# %% [markdown]
# # Building a `QFieldObject`
#
# This tutorial is a placeholder.
#
# It will explain the accepted input formats for `Q`, `S`, and `n`, and how a `QFieldObject` is initialized from them.
